# %%
from bs4 import BeautifulSoup
import requests
import time

# %%
print('put some skills not needed')
skills_not_needed = input('>')

print(f'Filtering out... {skills_not_needed}')

def find_jobs():
    html_text = requests.get('https://www.timesjobs.com/candidate/job-search.html?searchType=personalizedSearch&from=submit&txtKeywords=Data+Analyst&txtLocation=').text

    soup = BeautifulSoup(html_text, 'lxml')

    jobs = soup.find_all('li', class_ = 'clearfix job-bx wht-shd-bx')

    for index, job in enumerate(jobs):
        published_date = job.find('span', class_='sim-posted').span.text

        if 'few' in published_date:
            company_name = job.find('h3', class_='joblist-comp-name').text.replace(' ', '')
            skills = job.find('span', class_='srp-skills').text.replace(' ','')
            job_url = job.header.h2.a['href']


            #filtering needed skills
            if skills_not_needed not in skills:
                #with open(f'/{index}.txt', 'w') as f:
                    #f.write(f"Company Name: {company_name.strip()} \n")
                    #f.write(f"Required Skills: {skills.strip()} \n")
                    #f.write(f"More Info: {job_url}")
                    
                print(f"Company Name: {company_name.strip()}")
                print(f"Required Skills: {skills.strip()}")
                print(f"More Info: {job_url}")
                print(f'File Saved: {index}')

if __name__ == '__main__':
    while True:
        find_jobs()
        time_wait = 10
        print(f'Waiting {time_wait} seconds...')
        time.sleep(time_wait * 60)
# Out:
# put some skills not needed
# >js
# Filtering out... js
# Company Name: Electrobrainmoderntechnologiespvtltd
# (MoreJobs)
# Required Skills: DataIntegrity,DataAnalytics,SQLServer,RDBMS,Metadata
# More Info: https://www.timesjobs.com/job-detail/data-analyst-data-analyst-electrobrain-modern-technologies-pvt-ltd-ahmedabad-chennai-delhi-hyderabad-secunderabad-mumbai-2-to-6-yrs-jobid-nGEMXDochihzpSvf__PLUS__uAgZw==&source=srp
# File Saved: 0
# Company Name: cross-tabmarketingservicespvt.
# Required Skills: macros,vba,dataanalyst
# More Info: https://www.timesjobs.com/job-detail/data-analyst-cross-tab-marketing-services-pvt-mumbai-1-to-3-yrs-jobid-ZaHA0OcLtKZzpSvf__PLUS__uAgZw==&source=srp
# File Saved: 1
# Company Name: SEVENCONSULTANCY
# Required Skills: Bigdataanalyst,Dataanalyst,analyticaltools,collectingdata
# More Info: https://www.timesjobs.com/job-detail/data-analyst-seven-consultancy-mumbai-chennai-1-to-2-yrs-jobid-ZOOj__SLASH__6LpYKVzpSvf__PLUS__uAgZw==&source=srp
# File Saved: 3
# ...
